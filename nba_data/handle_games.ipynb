# %%
import os
import sys

# Get the current directory of the notebook
notebook_dir = os.path.dirname(os.path.abspath('__file__'))

# Get the parent directory (one level up)
parent_dir = os.path.dirname(notebook_dir)

# Add the parent directory to the system path
sys.path.append(parent_dir)
from utils import get_categorical_columns, get_numeric_columns, get_matchups

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### **Concatenating data**

# %%
dir_path = './raw_data/games'
csv_files = [f for f in os.listdir(dir_path) if f.endswith('.csv')]

# %%
dfs = []
for csv_file in csv_files:
    csv_path = os.path.join(dir_path, csv_file)
    df = pd.read_csv(csv_path)
    dfs.append(df)

df_raw = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# ### Defining mutual cols

# %%
mutual_cols = ['SEASON_ID_y', 'GAME_DATE_y', 'MATCHUP_y']

rename_mutuals = {
    'SEASON_ID_x': 'SEASON_ID',
    'GAME_DATE_x': 'GAME_DATE',
    'MATCHUP_x': 'MATCHUP',
    'GAME_ID': 'GAME_ID'
}

keys = list(rename_mutuals.values())

df_raw = df_raw.drop(columns=mutual_cols, axis=1)
df_raw = df_raw.rename(columns=rename_mutuals)

# %%
df_raw.head(3)
# Out:
#    SEASON_ID   TEAM_ID_x TEAM_ABBREVIATION_x    TEAM_NAME_x   GAME_ID  \
# 0      22013  1610612737                 ATL  Atlanta Hawks  21301166
# 1      22013  1610612737                 ATL  Atlanta Hawks  21300854
# 2      22013  1610612737                 ATL  Atlanta Hawks  21300460
#
#     GAME_DATE      MATCHUP WL_x  MIN_x  PTS_x  FGM_x  FGA_x  FG_PCT_x  FG3M_x  \
# 0  2014-04-09  ATL vs. BOS    W    240    105     40     76     0.526       9
# 1  2014-02-26    ATL @ BOS    L    240    104     38     76     0.500       9
# 2  2013-12-31    ATL @ BOS    W    240     92     33     91     0.363       5
#
#    FG3A_x  FG3_PCT_x  FTM_x  FTA_x  FT_PCT_x  OREB_x  DREB_x  REB_x  AST_x  \
# 0      23      0.391     16     22     0.727       8      35     43     30
# 1      19      0.474     19     24     0.792       6      23     29     23
# 2      29      0.172     21     25     0.840      15      36     51     21
#
#    STL_x  BLK_x  ...  PLUS_MINUS_x   TEAM_ID_y  TEAM_ABBREVIATION_y  \
# 0      7      5  ...           8.0  1610612738                  BOS
# 1      6      6  ...         -11.0  1610612738                  BOS
# 2      7      4  ...           1.0  1610612738                  BOS
#
#       TEAM_NAME_y WL_y MIN_y PTS_y  FGM_y  FGA_y  FG_PCT_y  FG3M_y  FG3A_y  \
# 0  Boston Celtics    L   240    97     37     84     0.440      12      26
# 1  Boston Celtics    W   240   115     43     90     0.478       8      22
# 2  Boston Celtics    L   239    91     35     84     0.417       5      20
#
#    FG3_PCT_y  FTM_y  FTA_y  FT_PCT_y  OREB_y  DREB_y  REB_y  AST_y  STL_y  \
# 0      0.462     11     14     0.786      11      28     39     25      7
# 1      0.364     21     23     0.913      14      32     46     24     10
# 2      0.250     16     17     0.941       8      39     47     28      6
#
#    BLK_y  TOV_y  PF_y  PLUS_MINUS_y
# 0      3     14    22          -8.0
# 1      1     14    24          11.0
# 2      7     15    22          -1.0
#
# [3 rows x 52 columns]

# %% [markdown]
# ### Define home and away Team

# %%
cols = list(df_raw.columns)

cols_x = [col for col in cols if col.endswith('_x')]
cols_y = [col for col in cols if col.endswith('_y')]

cols_x.extend(keys)
cols_y.extend(keys)

df_x = df_raw[cols_x]
df_y = df_raw[cols_y]

df_away_x = df_x[df_x['MATCHUP'].str.contains('@')]
df_home_x = df_x[df_x['MATCHUP'].str.contains('vs')]

df_away_y = df_y[df_y['MATCHUP'].str.contains('vs')]
df_home_y = df_y[df_y['MATCHUP'].str.contains('@')]

# %%
rename_cols_away_x = {col: col.replace('_x', '_AWAY') for col in df_away_x.columns}
rename_cols_away_y = {col: col.replace('_y', '_AWAY') for col in df_away_y.columns}

rename_cols_home_x = {col: col.replace('_x', '_HOME') for col in df_home_x.columns}
rename_cols_home_y = {col: col.replace('_y', '_HOME') for col in df_home_y.columns}

df_away_x = df_away_x.rename(columns=rename_cols_away_x)
df_away_y = df_away_y.rename(columns=rename_cols_away_y)

df_home_x = df_home_x.rename(columns=rename_cols_home_x)
df_home_y = df_home_y.rename(columns=rename_cols_home_y)

# %%
df_home = pd.concat([df_home_x, df_home_y])
df_away = pd.concat([df_away_x, df_away_y])

# %%
all_games = pd.merge(df_home, df_away, on=keys)

# %%
all_games
# Out:
#        TEAM_ID_HOME TEAM_ABBREVIATION_HOME         TEAM_NAME_HOME WL_HOME  \
# 0        1610612737                    ATL          Atlanta Hawks       W
# 1        1610612737                    ATL          Atlanta Hawks       L
# 2        1610612737                    ATL          Atlanta Hawks       W
# 3        1610612737                    ATL          Atlanta Hawks       W
# 4        1610612737                    ATL          Atlanta Hawks       L
# ...             ...                    ...                    ...     ...
# 12316    1610612752                    NYK        New York Knicks       W
# 12317    1610612754                    IND         Indiana Pacers       W
# 12318    1610612756                    PHX           Phoenix Suns       L
# 12319    1610612756                    PHX           Phoenix Suns       L
# 12320    1610612760                    OKC  Oklahoma City Thunder       W
#
#        MIN_HOME  PTS_HOME  FGM_HOME  FGA_HOME  FG_PCT_HOME  FG3M_HOME  \
# 0           240       105        40        76        0.526          9
# 1           240        87        36        93        0.387          5
# 2           240       117        48        82        0.585         13
# 3           239       108        47        91        0.516          8
# 4           240       105        38        85        0.447          8
# ...         ...       ...       ...       ...          ...        ...
# 12316       242       126        46       100        0.460         19
# 12317       240       152        55        95        0.579         20
# 12318       241       121        43        80        0.538         16
# 12319       239       114        42        83        0.506         18
# 12320       241       123        46        89        0.517         15
#
#        FG3A_HOME  FG3_PCT_HOME  FTM_HOME  FTA_HOME  FT_PCT_HOME  OREB_HOME  \
# 0             23         0.391        16        22        0.727          8
# 1             20         0.250        10        12        0.833         12
# 2             29         0.448         8        10        0.800          2
# 3             23         0.348         6        11        0.545         14
# 4             28         0.286        21        27        0.778          8
# ...          ...           ...       ...       ...          ...        ...
# 12316         42         0.452        15        22        0.682         13
# 12317         38         0.526        22        23        0.957          9
# 12318         32         0.500        19        26        0.731          5
# 12319         39         0.462        12        15        0.800          6
# 12320         39         0.385        16        20        0.800          4
#
#        DREB_HOME  REB_HOME  AST_HOME  STL_HOME  BLK_HOME  TOV_HOME  PF_HOME  \
# 0             35        43        30         7         5        14       14
# 1             26        38        23         8         3         8       26
# 2             36        38        35         1         3        16       17
# 3             36        50        31         6         3        12       18
# 4             26        34        22         7         3        16       29
# ...          ...       ...       ...       ...       ...       ...      ...
# 12316         34        47        28         7         0         3       14
# 12317         40        49        38         7         4        14       24
# 12318         29        34        26         5         4        14       15
# 12319         37        43        29         8         7        19       18
# 12320         36        40        34        19         6        15       17
#
#        PLUS_MINUS_HOME  SEASON_ID  ...   GAME_ID TEAM_ID_AWAY  \
# 0                  8.0      22013  ...  21301166   1610612738
# 1                 -7.0      22013  ...  21300190   1610612738
# 2                 19.0      22013  ...  21301132   1610612739
# 3                 19.0      22013  ...  21300282   1610612739
# 4                 -6.0      22013  ...  21301025   1610612740
# ...                ...        ...  ...       ...          ...
# 12316             21.0      22023  ...  22300161   1610612759
# 12317             41.0      22023  ...  22300146   1610612759
# 12318            -11.0      22023  ...  22300131   1610612759
# 12319             -1.0      22023  ...  22300113   1610612759
# 12320             36.0      22023  ...  22300021   1610612759
#
#        TEAM_ABBREVIATION_AWAY        TEAM_NAME_AWAY WL_AWAY MIN_AWAY PTS_AWAY  \
# 0                         BOS        Boston Celtics       L      240       97
# 1                         BOS        Boston Celtics       W      240       94
# 2                         CLE   Cleveland Cavaliers       L      239       98
# 3                         CLE   Cleveland Cavaliers       L      241       89
# 4                         NOP  New Orleans Pelicans       W      239      111
# ...                       ...                   ...     ...      ...      ...
# 12316                     SAS     San Antonio Spurs       L      240      105
# 12317                     SAS     San Antonio Spurs       L      242      111
# 12318                     SAS     San Antonio Spurs       W      239      132
# 12319                     SAS     San Antonio Spurs       W      239      115
# 12320                     SAS     San Antonio Spurs       L      241       87
#
#        FGM_AWAY  FGA_AWAY  FG_PCT_AWAY  FG3M_AWAY  FG3A_AWAY  FG3_PCT_AWAY  \
# 0            37        84        0.440         12         26         0.462
# 1            33        72        0.458          4         16         0.250
# 2            36        91        0.396          5         21         0.238
# 3            38        94        0.404          5         20         0.250
# 4            36        70        0.514          4         13         0.308
# ...         ...       ...          ...        ...        ...           ...
# 12316        44        90        0.489          9         34         0.265
# 12317        40        94        0.426          8         26         0.308
# 12318        51        98        0.520         18         37         0.486
# 12319        43        92        0.467         14         37         0.378
# 12320        36        93        0.387          9         30         0.300
#
#        FTM_AWAY  FTA_AWAY  FT_PCT_AWAY  OREB_AWAY  DREB_AWAY  REB_AWAY  \
# 0            11        14        0.786         11         28        39
# 1            24        31        0.774          7         40        47
# 2            21        25        0.840         10         24        34
# 3             8        17        0.471         16         31        47
# 4            35        43        0.814          7         33        40
# ...         ...       ...          ...        ...        ...       ...
# 12316         8        13        0.615         11         35        46
# 12317        23        30        0.767         12         24        36
# 12318        12        13        0.923          9         32        41
# 12319        15        20        0.750          8         29        37
# 12320         6         9        0.667         13         30        43
#
#        AST_AWAY  STL_AWAY  BLK_AWAY  TOV_AWAY  PF_AWAY  PLUS_MINUS_AWAY
# 0            25         7         3        14       22             -8.0
# 1            18         3         7        17       14              7.0
# 2            16        13         3         6       18            -19.0
# 3            19         4         2        11       11            -19.0
# 4            20        10         6        15       28              6.0
# ...         ...       ...       ...       ...      ...              ...
# 12316        31         2         7        13       22            -21.0
# 12317        26         7         5        11       15            -41.0
# 12318        37         7         5         8       21             11.0
# 12319        25        10         9        12       17              1.0
# 12320        24         7         6        24       13            -36.0
#
# [12321 rows x 52 columns]

# %% [markdown]
# ### Dropping columns

# %%
unuseful_cols = [
    'TEAM_ABBREVIATION_HOME',
    'TEAM_ABBREVIATION_AWAY'
]

# %%
all_games = all_games.drop(columns=unuseful_cols)

# %%
all_games
# Out:
#        TEAM_ID_HOME         TEAM_NAME_HOME WL_HOME  MIN_HOME  PTS_HOME  \
# 0        1610612737          Atlanta Hawks       W       240       105
# 1        1610612737          Atlanta Hawks       L       240        87
# 2        1610612737          Atlanta Hawks       W       240       117
# 3        1610612737          Atlanta Hawks       W       239       108
# 4        1610612737          Atlanta Hawks       L       240       105
# ...             ...                    ...     ...       ...       ...
# 12316    1610612752        New York Knicks       W       242       126
# 12317    1610612754         Indiana Pacers       W       240       152
# 12318    1610612756           Phoenix Suns       L       241       121
# 12319    1610612756           Phoenix Suns       L       239       114
# 12320    1610612760  Oklahoma City Thunder       W       241       123
#
#        FGM_HOME  FGA_HOME  FG_PCT_HOME  FG3M_HOME  FG3A_HOME  FG3_PCT_HOME  \
# 0            40        76        0.526          9         23         0.391
# 1            36        93        0.387          5         20         0.250
# 2            48        82        0.585         13         29         0.448
# 3            47        91        0.516          8         23         0.348
# 4            38        85        0.447          8         28         0.286
# ...         ...       ...          ...        ...        ...           ...
# 12316        46       100        0.460         19         42         0.452
# 12317        55        95        0.579         20         38         0.526
# 12318        43        80        0.538         16         32         0.500
# 12319        42        83        0.506         18         39         0.462
# 12320        46        89        0.517         15         39         0.385
#
#        FTM_HOME  FTA_HOME  FT_PCT_HOME  OREB_HOME  DREB_HOME  REB_HOME  \
# 0            16        22        0.727          8         35        43
# 1            10        12        0.833         12         26        38
# 2             8        10        0.800          2         36        38
# 3             6        11        0.545         14         36        50
# 4            21        27        0.778          8         26        34
# ...         ...       ...          ...        ...        ...       ...
# 12316        15        22        0.682         13         34        47
# 12317        22        23        0.957          9         40        49
# 12318        19        26        0.731          5         29        34
# 12319        12        15        0.800          6         37        43
# 12320        16        20        0.800          4         36        40
#
#        AST_HOME  STL_HOME  BLK_HOME  TOV_HOME  PF_HOME  PLUS_MINUS_HOME  \
# 0            30         7         5        14       14              8.0
# 1            23         8         3         8       26             -7.0
# 2            35         1         3        16       17             19.0
# 3            31         6         3        12       18             19.0
# 4            22         7         3        16       29             -6.0
# ...         ...       ...       ...       ...      ...              ...
# 12316        28         7         0         3       14             21.0
# 12317        38         7         4        14       24             41.0
# 12318        26         5         4        14       15            -11.0
# 12319        29         8         7        19       18             -1.0
# 12320        34        19         6        15       17             36.0
#
#        SEASON_ID   GAME_DATE      MATCHUP   GAME_ID  TEAM_ID_AWAY  \
# 0          22013  2014-04-09  ATL vs. BOS  21301166    1610612738
# 1          22013  2013-11-23  ATL vs. BOS  21300190    1610612738
# 2          22013  2014-04-04  ATL vs. CLE  21301132    1610612739
# 3          22013  2013-12-06  ATL vs. CLE  21300282    1610612739
# 4          22013  2014-03-21  ATL vs. NOP  21301025    1610612740
# ...          ...         ...          ...       ...           ...
# 12316      22023  2023-11-08    SAS @ NYK  22300161    1610612759
# 12317      22023  2023-11-06    SAS @ IND  22300146    1610612759
# 12318      22023  2023-11-02    SAS @ PHX  22300131    1610612759
# 12319      22023  2023-10-31    SAS @ PHX  22300113    1610612759
# 12320      22023  2023-11-14    SAS @ OKC  22300021    1610612759
#
#              TEAM_NAME_AWAY WL_AWAY  MIN_AWAY  PTS_AWAY  FGM_AWAY  FGA_AWAY  \
# 0            Boston Celtics       L       240        97        37        84
# 1            Boston Celtics       W       240        94        33        72
# 2       Cleveland Cavaliers       L       239        98        36        91
# 3       Cleveland Cavaliers       L       241        89        38        94
# 4      New Orleans Pelicans       W       239       111        36        70
# ...                     ...     ...       ...       ...       ...       ...
# 12316     San Antonio Spurs       L       240       105        44        90
# 12317     San Antonio Spurs       L       242       111        40        94
# 12318     San Antonio Spurs       W       239       132        51        98
# 12319     San Antonio Spurs       W       239       115        43        92
# 12320     San Antonio Spurs       L       241        87        36        93
#
#        FG_PCT_AWAY  FG3M_AWAY  FG3A_AWAY  FG3_PCT_AWAY  FTM_AWAY  FTA_AWAY  \
# 0            0.440         12         26         0.462        11        14
# 1            0.458          4         16         0.250        24        31
# 2            0.396          5         21         0.238        21        25
# 3            0.404          5         20         0.250         8        17
# 4            0.514          4         13         0.308        35        43
# ...            ...        ...        ...           ...       ...       ...
# 12316        0.489          9         34         0.265         8        13
# 12317        0.426          8         26         0.308        23        30
# 12318        0.520         18         37         0.486        12        13
# 12319        0.467         14         37         0.378        15        20
# 12320        0.387          9         30         0.300         6         9
#
#        FT_PCT_AWAY  OREB_AWAY  DREB_AWAY  REB_AWAY  AST_AWAY  STL_AWAY  \
# 0            0.786         11         28        39        25         7
# 1            0.774          7         40        47        18         3
# 2            0.840         10         24        34        16        13
# 3            0.471         16         31        47        19         4
# 4            0.814          7         33        40        20        10
# ...            ...        ...        ...       ...       ...       ...
# 12316        0.615         11         35        46        31         2
# 12317        0.767         12         24        36        26         7
# 12318        0.923          9         32        41        37         7
# 12319        0.750          8         29        37        25        10
# 12320        0.667         13         30        43        24         7
#
#        BLK_AWAY  TOV_AWAY  PF_AWAY  PLUS_MINUS_AWAY
# 0             3        14       22             -8.0
# 1             7        17       14              7.0
# 2             3         6       18            -19.0
# 3             2        11       11            -19.0
# 4             6        15       28              6.0
# ...         ...       ...      ...              ...
# 12316         7        13       22            -21.0
# 12317         5        11       15            -41.0
# 12318         5         8       21             11.0
# 12319         9        12       17              1.0
# 12320         6        24       13            -36.0
#
# [12321 rows x 50 columns]

# %%
all_games.columns
# Out:
# Index(['TEAM_ID_HOME', 'TEAM_NAME_HOME', 'WL_HOME', 'MIN_HOME', 'PTS_HOME',
#        'FGM_HOME', 'FGA_HOME', 'FG_PCT_HOME', 'FG3M_HOME', 'FG3A_HOME',
#        'FG3_PCT_HOME', 'FTM_HOME', 'FTA_HOME', 'FT_PCT_HOME', 'OREB_HOME',
#        'DREB_HOME', 'REB_HOME', 'AST_HOME', 'STL_HOME', 'BLK_HOME', 'TOV_HOME',
#        'PF_HOME', 'PLUS_MINUS_HOME', 'SEASON_ID', 'GAME_DATE', 'MATCHUP',
#        'GAME_ID', 'TEAM_ID_AWAY', 'TEAM_NAME_AWAY', 'WL_AWAY', 'MIN_AWAY',
#        'PTS_AWAY', 'FGM_AWAY', 'FGA_AWAY', 'FG_PCT_AWAY', 'FG3M_AWAY',
#        'FG3A_AWAY', 'FG3_PCT_AWAY', 'FTM_AWAY', 'FTA_AWAY', 'FT_PCT_AWAY',
#        'OREB_AWAY', 'DREB_AWAY', 'REB_AWAY', 'AST_AWAY', 'STL_AWAY',
#        'BLK_AWAY', 'TOV_AWAY', 'PF_AWAY', 'PLUS_MINUS_AWAY'],
#       dtype='object')

# %%
all_games.to_csv('./data/games.csv', index=False)

# %%
all_games[all_games['SEASON_ID'] == 22023].to_csv('training.csv')
